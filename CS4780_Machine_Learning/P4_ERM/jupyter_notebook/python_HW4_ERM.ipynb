# %% [markdown]
# <h2>Project 4: Empirical Risk Minimization</h2>
#
# <blockquote>
#     <center>
#     <img src="./spam.jpeg" width="200px" />
#     </center>
#       <p><cite><center>"One person's spam is another person's dinner."<br>
#        -- ancient German wisdon
#       </center></cite></p>
# </blockquote>
#
# <h3>Introduction</h3>
#
# <p>
#     In this project you will be building an email spam filter.</p>
#
# <strong>How to submit:</strong> You can submit your code using the red <strong>Submit</strong> button above. This button will send any code below surrounded by <strong>#&lt;GRADED&gt;</strong><strong>#&lt;/GRADED&gt;</strong> tags below to the autograder, which will then run several tests over your code. By clicking on the <strong>Details</strong> dropdown next to the Submit button, you will be able to view your submission report once the autograder has completed running. This submission report contains a summary of the tests you have failed or passed, as well as a log of any errors generated by your code when we ran it.
#
# Note that this may take a while depending on how long your code takes to run! Once your code is submitted you may navigate away from the page as you desire -- the most recent submission report will always be available from the Details menu.
#
# <p><strong>Evaluation:</strong> Your code will be autograded for technical
# correctness and--on some assignments--speed. Please <em>do not</em> change the names of any provided functions or classes within the code, or you will wreak havoc on the autograder. Furthermore, <em>any code not surrounded by <strong>#&lt;GRADED&gt;</strong><strong>#&lt;/GRADED&gt;</strong> tags will not be run by the autograder</em>. However, the correctness of your implementation -- not the autograder's output -- will be the final judge of your score.  If necessary, we will review and grade assignments individually to ensure that you receive due credit for your work.
#
# <p><strong>Academic Integrity:</strong> We will be checking your code against other submissions in the class for logical redundancy. If you copy someone else's code and submit it with minor changes, we will know. These cheat detectors are quite hard to fool, so please don't try. We trust you all to submit your own work only; <em>please</em> don't let us down. If you do, we will pursue the strongest consequences available to us.
#
# <p><strong>Getting Help:</strong> You are not alone!  If you find yourself stuck  on something, contact the course staff for help.  Office hours, section, and the <a href="https://piazza.com/class/jcb1ar25kjd5vq">Piazza</a> are there for your support; please use them.  If you can't make our office hours, let us know and we will schedule more.  We want these projects to be rewarding and instructional, not frustrating and demoralizing.  But, we don't know when or how to help unless you ask.

# %% [markdown]
# <h3>Computing derivatives</h3>
#
# <p>  Before you dive into the programming part of this assignment you will need to derive the gradients for several loss functions.
#     <b>Please write your calculation in a comment block within your code.</b>
# </p>
#
# <p>   Derive the gradient function for each of the following loss functions with respect to the weight vector $w$. Write down the gradient update (with stepsize $c$). <br>
# (Note that:    $\|w\|_2^2=w^\top w$ and  $\lambda$ is a  non-negative constant.)
# </p>
#
# <ol>
#     <li> Ridge Regression: ${\cal L}(w)=\frac{1}{n}\sum_{i=1}^n (w^\top x_i-y_i)^2+\lambda \|w\|_2^2$ </li>
#     <li> Ridge Gradient: $\frac{2}{n}\sum_{i=1}^n (w^\top x_i-y_i)*(x_1)+2\lambda w$ <li>
#     <li> Logistic Regression: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \log(1+\exp{(-y_i w^\top x_i)})$ </li>
#     <li> Logistic Gradient: ($y_i\in\{+1,-1\}$): $\sum_{i=1}^n \frac{(-y_i x_i)\exp{(-y_i w^\top x_i)}}{1+\exp{(-y_i w^\top x_i)}}$ <li>
#     <li> Hinge loss: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \max \left(1-y_i(w^\top x_i+b),0\right)+\lambda \|w\|_2^2$ </li>
#     <li> Hinge Gradient: $\sum_{i=1}^n -\delta(y_i(w^\top x_i+b)<1)x_i y_i + 2\lambda w$<li>
# </ol>

# %% [markdown]
# <h3>Building an email spam filter</h3>
# <p> You will now implement ridge loss and the Adagrad algorithm.
#
# The function below loads in pre-processed email data, where emails are represented as bag-of-words vectors.
# </p>

# %%
#<GRADED>
import numpy as np
#</GRADED>
import matplotlib
matplotlib.use('PDF')
import matplotlib.pyplot as plt
from numpy.matlib import repmat
import sys
from scipy.io import loadmat
import time

# %matplotlib inline

# %%
# tokenize the email and hashes the symbols into a vector
def extractfeaturesnaive(path, B):
    with open(path, 'r') as femail:
        # initialize all-zeros feature vector
        v = np.zeros(B)
        email = femail.read()
        # breaks for non-ascii characters
        tokens = email.split()
        for token in tokens:
            v[hash(token) % B] = 1
    return v

def loadspamdata(extractfeatures, B=512, path="../resource/lib/public/data_train/"):
    '''
    INPUT:
    extractfeatures : function to extract features
    B               : dimensionality of feature space
    path            : the path of folder to be processed
    
    OUTPUT:
    X, Y
    '''
    if path[-1] != '/':
        path += '/'
    
    with open(path + 'index', 'r') as f:
        allemails = [x for x in f.read().split('\n') if ' ' in x]
    
    xs = np.zeros((len(allemails), B))
    ys = np.zeros(len(allemails))
    for i, line in enumerate(allemails):
        label, filename = line.split(' ')
        # make labels +1 for "spam" and -1 for "ham"
        ys[i] = (label == 'spam') * 2 - 1
        xs[i, :] = extractfeatures(path + filename, B)
    print('Loaded %d input emails.' % len(ys))
    return xs, ys

X,Y = loadspamdata(extractfeaturesnaive)
X.shape
# Out:
# Loaded 5000 input emails.
# (5000, 512)

# %% [markdown]
# This is your training set. To evaluate your algorithm you should split it off into a validation set.

# %%
# Split data into training and validation
n, d = X.shape
cutoff = int(np.ceil(0.8 * n))
# indices of training samples
xTr = X[:cutoff,:]
yTr = Y[:cutoff]
# indices of testing samples
xTv = X[cutoff:,:]
yTv = Y[cutoff:]

# %% [markdown]
# <p>This should generate a training data set <code>xTr</code>, <code>yTr</code> and a validation set <code>xTv</code>, <code>yTv</code> for you. </p>
#
# <p>It is now time to implement your classifiers. We will always use the Adagrad gradient descent algorithm, but with various loss functions.
# First implement the function <code>ridge</code> which computes the ridge regression loss and gradient for a particular data set <code>xTr</code>, <code>yTr</code> and a weight vector <code>w</code>. Make sure you don't forget to incorporate your regularization constant $\lambda$. </p>

# %%
#<GRADED>
def ridge(w,xTr,yTr,lmbda):
    """
    INPUT:
    w     : d   dimensional weight vector
    xTr   : nxd dimensional matrix (each row is an input vector)
    yTr   : n   dimensional vector (each entry is a label)
    lmbda : regression constant (scalar)
    
    OUTPUTS:
    loss     : the total loss obtained with w on xTr and yTr (scalar)
    gradient : d dimensional gradient at w
    """
    n, d = xTr.shape
    
    ## fill in your code here
#     raise NotImplementedError('Your code goes here!')
#     loss1=(w.T.dot(xTr)-yTr).T.dot(w.T.dot(xTr)-yTr)/n
    loss1=(((xTr.dot(w)-yTr).T).dot(xTr.dot(w)-yTr))/n
    regu1=lmbda*(w.T.dot(w))
    
    loss=loss1+regu1
    
#     grad=2*(w.T.dot(xTr)-yTr).T.dot(w.T.dot(xTr)-yTr)/n
    grad2=2*xTr.T.dot(xTr.dot(w)-yTr)/n
    regu2=lmbda*2*w
    
    gradient=grad2+regu2
    
    return loss, gradient
#</GRADED>

# %% [markdown]
# <p>An  alternative to  deriving the gradient analytically is to estimate it numerically. This is very slow, but it is a convenient  way to check your code for correctness.  The following function  uses numerical differentiation to evaluate the correctness of ridge.  If your code is correct, the norm difference between the two should be very small (smaller than $10^{-8}$).
# Keep in mind that this only checks if the gradient corresponds to the loss, but not if the loss is correct. The function also plots an image of the gradient values (blue) and their estimates (red). If everything is correct, these two should be right on top of each other.
# </p>

# %%
def numericalgradient(fun,w,e):
    # get dimensionality
    d = len(w)
    # initialize numerical derivative
    dh = np.zeros(d)
    # go through dimensions
    for i in range(d):
        # copy the weight vector
        nw = w.copy()
        # perturb dimension i
        nw[i] += e
        # compute loss
        l1, temp = fun(nw)
        # perturb dimension i again
        nw[i] -= 2*e
        # compute loss
        l2, temp = fun(nw)
        # the gradient is the slope of the loss
        dh[i] = (l1 - l2) / (2*e)
    return dh

def checkgrad(fun,w,e):
    # evaluate symbolic gradient from fun()
    loss,dy = fun(w)
    # estimate gradient numerically from fun()
    dh = numericalgradient(fun,w,e)
    
    # ii = dy.argsort()
    ii = np.array([i for i in range(len(dy))])
    
    plt.figure(figsize=(10,6))
    plt.scatter([i for i in range(len(dy))], dh[ii], c='b', marker='o', s=60)
    plt.scatter([i for i in range(len(dy))], dy[ii], c='r', marker='.', s=50)
    plt.xlabel('Dimension')
    plt.ylabel('Gradient value')
    plt.legend(["numeric","symbolic"])
    
    # return the norm of the difference scaled by the norm of the sum
    return np.linalg.norm(dh - dy) / np.linalg.norm(dh + dy)

# set lmbda (λ) arbitrarily
lmbda = 0.1
# dimensionality of the input
_, d = xTr.shape
# evaluate loss on random vector
w = np.random.rand(d)
# the lambda function notation is an inline way to define a function with only a single argument.
ratio = checkgrad(lambda weight: ridge(weight,xTr,yTr,lmbda),w,1e-05)
print("The norm ratio is %.10f." % ratio)
# Out:
# The norm ratio is 0.0000000004.

# %% [markdown]
# <p>Implement the function <code>adagrad</code> which performs adaptive gradient descent.
# Make sure to include the tolerance variable to stop early if the norm of the gradient is less than the tolerance value (you can use the function <code>np.linalg.norm(x)</code>). When the norm of the gradient is tiny it means that you have arrived at a minimum.  <br>
# The first parameter of <code>adagrad</code> is a function which takes a weight vector and returns loss and gradient.
# </p>

# %%
#<GRADED>
def adagrad(func,w,alpha,maxiter,eps,delta=1e-02):
    """
    INPUT:
    func    : function to minimize
              (loss, gradient = func(w))
    w       : d dimensional initial weight vector 
    alpha   : initial gradient descent stepsize (scalar)
    maxiter : maximum amount of iterations (scalar)
    eps     : epsilon value
    delta   : if norm(gradient)<delta, it quits (scalar)
    
    OUTPUTS:
     
    w      : d dimensional final weight vector
    losses : vector containing loss at each iteration
    """

    ## fill in your code here
#     raise NotImplementedError('Your code goes here!')
#     loss, gradient=func(w)
#     for i in range(maxiter):
#         loss, gradient=func(w)
#         if np.linalg.norm(gradient)<delta:
#             return w, losses
#         z=z+gradient*gradient
#         w=w-alpha*gradient/np.sqrt(z+eps)
#         loss, gradient=func(w)
#         losses[i]=loss
    
#     return 

    d=w.shape
    z=np.zeros(d)
    losses = np.zeros(maxiter)
    k=0
    loss, gradient=func(w)
    w1=w
    
    while k<maxiter:
        losses[k], gradient=func(w1)
        z=z+gradient*gradient
        w1=w1-alpha*gradient/np.sqrt(z+eps)
        if np.linalg.norm(gradient)<delta:
#             return w1, losses[:k+1]
              losses=losses[:k+1]
              break
#         gradient=gradient1
#         loss=loss1
        k=k+1
        
    return w1, losses
        
#</GRADED>

# %%
_, d = xTr.shape
eps = 1e-06
w, losses = adagrad(lambda weight: ridge(weight, xTr, yTr, lmbda), np.random.rand(d), 1, 1000, eps)

plt.figure(figsize=(10,6))
plt.semilogy(losses, c='r', linestyle='-')
plt.xlabel("gradient updates")
plt.ylabel("loss")
plt.title("Adagrad convergence")
print("Final loss: %f" % losses[-1])
# Out:
# Final loss: 0.339513

# %% [markdown]
# <p> Write the (almost trivial) function <code>linclassify</code> which returns the predictions for a vector <code>w</code> and a data set <code>xTv</code>. (You can take it from a previous project.)</p>
#
# <p>After this you can check your training and validation accuracy by running the cell below.</p>

# %%
#<GRADED>
def linclassify(w,xTr):
    ## fill in your code here
    return np.sign(xTr.dot(w))
#</GRADED>

# evaluate training accuracy
preds = linclassify(w,xTr)
trainingacc = np.mean(preds==yTr)
# evaluate testing accuracy
preds = linclassify(w,xTv)
validationacc = np.mean(preds==yTv)
print("Training accuracy %2.2f%%\nValidation accuracy %2.2f%%\n" % (trainingacc*100,validationacc*100))
# Out:
# Training accuracy 96.15%
# Validation accuracy 91.50%

# %% [markdown]
# <p>Now implement the two other loss functions, <code>logistic</code> and <code>hinge</code>. Start off with <code>logistic</code>:</p>

# %% [markdown]
# <ol>
#     <li> Ridge Regression: ${\cal L}(w)=\frac{1}{n}\sum_{i=1}^n (w^\top x_i-y_i)^2+\lambda \|w\|_2^2$ </li>
#     <li> Ridge Gradient: $\frac{2}{n}\sum_{i=1}^n (w^\top x_i-y_i)*(x_1)+2\lambda w$ <li>
#     <li> Logistic Regression: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \log(1+\exp{(-y_i w^\top x_i)})$ </li>
#     <li> Logistic Gradient: ($y_i\in\{+1,-1\}$): $\sum_{i=1}^n \frac{(-y_i x_i)\exp{(-y_i w^\top x_i)}}{1+\exp{(-y_i w^\top x_i)}}$ <li>
#     <li> Hinge loss: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \max \left(1-y_i(w^\top x_i+b),0\right)+\lambda \|w\|_2^2$ </li>
#     <li> Hinge Gradient: $\sum_{i=1}^n -\delta(y_i(w^\top x_i+b)<1)x_i y_i + 2\lambda w$<li>
# </ol>

# %%
#<GRADED>
def logistic(w,xTr,yTr):
    """
    INPUT:
    w     : d   dimensional weight vector
    xTr   : nxd dimensional matrix (each row is an input vector)
    yTr   : n   dimensional vector (each entry is a label)
    
    OUTPUTS:
    loss     : the total loss obtained with w on xTr and yTr (scalar)
    gradient : d dimensional gradient at w
    """
    ## fill in your code here
    n, d = xTr.shape
    
    loss=np.sum(np.log(np.exp(-(xTr.dot(w))*yTr)+1))
#     nominator = -np.exp(-(xTr.dot(w))*yTr)*xTr.T*yTr
    nominator=-np.exp(-(xTr.dot(w))*yTr).reshape((n,1))*(yTr.reshape((n,1))*xTr)
    denom = 1+np.exp(-(xTr.dot(w))*yTr)
    
    gradient=sum(nominator * (1/denom).reshape(n,1))
    
    return loss, gradient
#     raise NotImplementedError('Your code goes here!')
#</GRADED>

# %% [markdown]
# <p>You can use the two cells below to test how well this loss function performs.</p>

# %%
# Gradient sanity check
_, d = xTr.shape
w = np.random.rand(d)
ratio = checkgrad(lambda weight: logistic(weight,xTr,yTr),w,1e-05)
print("The norm ratio is %.10f." % ratio)
# Out:
# The norm ratio is 0.0000000005.

# %%
w, losses = adagrad(lambda weight: logistic(weight, xTr, yTr), np.random.rand(d), 1, 1000, 1e-06)

# evaluate training accuracy
preds = linclassify(w,xTr)
trainingacc = np.mean(preds==yTr)
# evaluate testing accuracy
preds = linclassify(w,xTv)
validationacc = np.mean(preds==yTv)
print("Training accuracy %2.2f%%\nValidation accuracy %2.2f%%\n" % (trainingacc*100,validationacc*100))
# Out:
# Training accuracy 99.50%
# Validation accuracy 89.10%

# %% [markdown]
# <ol>
#     <li> Ridge Regression: ${\cal L}(w)=\frac{1}{n}\sum_{i=1}^n (w^\top x_i-y_i)^2+\lambda \|w\|_2^2$ </li>
#     <li> Ridge Gradient: $\frac{2}{n}\sum_{i=1}^n (w^\top x_i-y_i)*(x_1)+2\lambda w$ <li>
#     <li> Logistic Regression: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \log(1+\exp{(-y_i w^\top x_i)})$ </li>
#     <li> Logistic Gradient: ($y_i\in\{+1,-1\}$): $\sum_{i=1}^n \frac{(-y_i x_i)\exp{(-y_i w^\top x_i)}}{1+\exp{(-y_i w^\top x_i)}}$ <li>
#     <li> Hinge loss: ($y_i\in\{+1,-1\}$): ${\cal L}(w)=\sum_{i=1}^n \max \left(1-y_i(w^\top x_i+b),0\right)+\lambda \|w\|_2^2$ </li>
#     <li> Hinge Gradient: $\sum_{i=1}^n -\delta(y_i(w^\top x_i+b)<1)x_i y_i + 2\lambda w$<li>
# </ol>

# %% [markdown]
# <p>Now implement <code>hinge</code>:</p>

# %%
#<GRADED>
def hinge(w,xTr,yTr,lmbda):
    """
    INPUT:
    w     : d   dimensional weight vector
    xTr   : nxd dimensional matrix (each row is an input vector)
    yTr   : n   dimensional vector (each entry is a label)
    lmbda : regression constant (scalar)
    
    OUTPUTS:
    loss     : the total loss obtained with w on xTr and yTr (scalar)
    gradient : d dimensional gradient at w
    """
    n, d = xTr.shape
    
    content=xTr.dot(w)*yTr
    loss=np.sum(np.maximum(0, 1-content))+lmbda*w.dot(w)
#     x,_ = content.shape
#     for i in range(x):
#         if content[i]<1:
#             content[i]=-1
#         else: content[i]=0
    
#     gradient=(content*yTr+2).reshape((n,1))*yTr+2*lmbda*w
    gradient=-np.dot((content<1)*yTr, xTr)+2*lmbda*w
#     print(((content<1)*yTr).shape)
#     print(np.dot((content<1)*yTr, xTr).shape)
    
    
    return loss, gradient
    
    ## fill in your code here
#</GRADED>

# %% [markdown]
# <p>You can use the two cells below to test how well this loss function performs.</p>

# %%
# Gradient sanity check
lmbda = 0.1
_, d = xTr.shape
w = np.random.rand(d)
ratio = checkgrad(lambda weight: hinge(weight,xTr,yTr,lmbda),w,1e-05)
print("The norm ratio is %.10f." % ratio)
# Out:
# The norm ratio is 0.0000000009.

# %%
w, losses = adagrad(lambda weight: hinge(weight, xTr, yTr, lmbda), np.random.rand(d), 1, 1000, 1e-06)

# evaluate training accuracy
preds = linclassify(w,xTr)
trainingacc = np.mean(preds==yTr)
# evaluate testing accuracy
preds = linclassify(w,xTv)
validationacc = np.mean(preds==yTv)
print("Training accuracy %2.2f%%\nValidation accuracy %2.2f%%\n" % (trainingacc*100,validationacc*100))
# Out:
# Training accuracy 96.83%
# Validation accuracy 85.90%

# %% [markdown]
# <h3>Competition <b>(Extra Credit, up to 10 points)</b></h3>
#
# <p>The competition for this assignment is split into two components:</p>
#
# <ol>
# <li><b>Feature Extraction</b>:
# Modify the function <code>extractfeaturescomp</code>.
# This function takes in a file path <code>path</code> and
# a feature dimension <code>B</code> and should output a feature vector of dimension <code>B</code>.
# The autograder will pass in a file path pointing to a file that contains an email,
# and set <code>B</code> = <code>feature_dimension</code>.
# We provide <code>extractfeaturesnaive</code> as an example.
# </li>
# <li><b>Model Training</b>:
# Modify the function <code>trainspamfiltercomp</code>.
# This function takes in training data <code>xTr</code> and training labels <code>yTr</code> and
# should output a weight vector <code>w</code> for linear classification.
# We provide an initial implementation using Adagrad and ridge regression.
# </li>
# </ol>
#
# <p>Your model will be trained on the same training set above (loaded by <code>loadspamdata</code>), but we will test its accuracy on a secret dataset of emails.</p>

# %%
#<GRADED>
num_sentFromWho = 1
num_sentFromWhichAddress = 600
num_wordsInSubject = 200
other_custom_features_dim = 10
one_hot_dim = 800
bigram_dim = 800

feature_dimension = one_hot_dim + bigram_dim + num_sentFromWho + num_sentFromWhichAddress + num_wordsInSubject + other_custom_features_dim

def extractfeaturescomp(path, B): 
    '''
    INPUT:
    path : file path of email
    B    : dimensionality of feature vector
    
    OUTPUTS:
    x    : B dimensional vector
    '''
    num_sentFromWho = 1
    num_sentFromWhichAddress = 600
    num_wordsInSubject = 200
    other_custom_features_dim = 10
    one_hot_dim = 800
    bigram_dim = 800

    custom_features_dim = num_sentFromWho + num_sentFromWhichAddress + num_wordsInSubject + other_custom_features_dim
    
    
#     B -= custom_features_dim
    x_oneHot = np.zeros(one_hot_dim)
    x_bigram = np.zeros(bigram_dim)
    x_who = np.zeros(num_sentFromWho)
    x_which = np.zeros(num_sentFromWhichAddress)
    x_subject = np.zeros(num_wordsInSubject)
    x_others = np.zeros(other_custom_features_dim)
    
    with open(path, 'r') as femail:
        email = femail.read()
        # breaks for non-ascii characters
        #print(email)
        dotComCount = 0
        wwwCount = 0
        dollarCount = 0
        capCount = 0
        fullCapCount = 0
        
        # one-hot
        tokens = email.split()
        #print(tokens)
        prev = '<s>'
        for token in tokens:
            #print(token+"|"+prev)
            if ".com" in token: dotComCount += 1
            if "www" in token: wwwCount += 1
            if "$" in token: dollarCount += 1
            if token.isupper(): fullCapCount += 1
            if not token.isupper() and not token.islower(): capCount += 1
            x_oneHot[hash(token) % one_hot_dim] = 1
            x_bigram[hash(token+"|"+prev) % bigram_dim] = 1
            prev = token
        
        # address <– to identify spam senders
        sentFromWho = tokens[1]
        
        if '@' in sentFromWho:
            sentFromWhichAddress = tokens[1].split('@')[1]
        else: sentFromWhichAddress = '<UNK>'
        #print(sentFromWhichAddress)
        x_who[hash(sentFromWho) % num_sentFromWho] = 1
        x_which[hash(sentFromWho) % num_sentFromWhichAddress] = 1
        
        
        subject_exclamtionMark = 0
        subject_questionMark = 0
        subject_free = 0
        subject_money = 0
        # subjects of spam likely have similar words
        if 'Subject:' in tokens and num_wordsInSubject>0:
#             subject = []
            for i in range(tokens.index('Subject:')+1,tokens.index('Date:')):
                if "X-" in tokens[i]: break
#                 subject.append(tokens[i])
                x_subject[hash(tokens[i]) % num_wordsInSubject] = 1
                if "!" in tokens[i]: x_others[6] = 1
                if "?" in tokens[i]: x_others[7] = 1
                if "free" in tokens[i] or "FREE" in tokens[i] or "Free" in tokens[i]: x_others[8] = 1
                if "money" in tokens[i] or "Money" in tokens[i]: x_others[9] = 1
#             if "!" in subject: x_others[6] = 1
#             if "?" in subject: x_others[7] = 1
#             if "free" in subject or "FREE" in subject or "Free" in subject: x_others[8] = 1
#             if "money" in subject or "Money" in subject: x_others[9] = 1


            #print(subject)
        # .com count <– spam likely has more links
        x_others[0] = 1 if dotComCount>0 else 0
        x_others[1] = 1 if wwwCount>0 else 0
        x_others[2] = 1 if dollarCount>0 else 0
        x_others[3] = len(tokens) # more effort into email = not spam?
        x_others[4] = capCount
        x_others[5] = fullCapCount
    
    x = np.concatenate((x_oneHot, x_bigram, x_who, x_which, x_subject, x_others), axis=None)
    return x
#</GRADED>

# %%
#<GRADED>
def trainspamfiltercomp(xTr, yTr):
    '''
    INPUT:
    xTr : nxd dimensional matrix (each row is an input vector)
    yTr : n   dimensional vector (each entry is a label)
    
    OUTPUTS:
    w : d dimensional vector for linear classification
    '''
    d = np.shape(xTr)[1]
    w = np.random.rand(np.shape(xTr)[1])
    lmbda = 0.1
#     return w
    w, losses = adagrad(lambda weight: hinge(weight, xTr, yTr, lmbda), np.random.rand(d), 1, 2000, 1e-06)
    return w
    
#</GRADED>

# %%
Xcomp, Ycomp = loadspamdata(extractfeaturescomp, B=feature_dimension, path="../resource/lib/public/data_train/")
# Out:
# Loaded 5000 input emails.

# %%
np.shape(Xcomp)
# Out:
# (5000, 2411)

# %%
# Split data into training and validation
n, _ = Xcomp.shape
cutoff = int(np.ceil(0.8 * n))
# indices of training samples
xTr = Xcomp[:cutoff,:]
yTr = Ycomp[:cutoff]
# indices of testing samples
xTv = Xcomp[cutoff:,:]
yTv = Ycomp[cutoff:]

# %%
for i in range(3):
    wcomp = trainspamfiltercomp(xTr, yTr)

    # evaluate training accuracy
    preds = linclassify(wcomp,xTr)
    trainingacc = np.mean(preds==yTr)
    # evaluate testing accuracy
    preds = linclassify(wcomp,xTv)
    validationacc = np.mean(preds==yTv)
    print("Training accuracy %2.2f%%\nValidation accuracy %2.2f%%\n" % (trainingacc*100,validationacc*100))
# Out:
# Training accuracy 100.00%
# Validation accuracy 91.90%
#
# Training accuracy 98.92%
# Validation accuracy 90.50%
#
# Training accuracy 100.00%
# Validation accuracy 93.30%

# %%
def loadspamdata2(extractfeatures, B=512, path="../resource/lib/public/data_train/"):
    '''
    INPUT:
    extractfeatures : function to extract features
    B               : dimensionality of feature space
    path            : the path of folder to be processed
    
    OUTPUT:
    X, Y
    '''
    maximum = 100
    if path[-1] != '/':
        path += '/'
    
    count = 0
    with open(path + 'index', 'r') as f:
        allemails = [x for x in f.read().split('\n') if ' ' in x]
        
    
    xs = np.zeros((len(allemails), B))
    ys = np.zeros(len(allemails))
    for i, line in enumerate(allemails):
        if i>maximum: break
        label, filename = line.split(' ')
        # make labels +1 for "spam" and -1 for "ham"
        ys[i] = (label == 'spam') * 2 - 1
        xs[i, :] = extractfeatures(path + filename, B)
    print('Loaded %d input emails.' % len(ys))
    return xs, ys

# %%
loadspamdata2(extractfeaturescomp, B=feature_dimension, path="../resource/lib/public/data_train/")
# Out:
# ['*THE', 'LEGAL', 'CABLE', 'TV', 'DESCRAMBLER*']
# ['Spend', 'Too', 'Much', 'On', 'Your', 'Phone', 'Bill?', '25711']
# ['Your', 'Membership', 'Exchange,', 'Issue', '#422']
# []
# ['The', 'Hottest', 'Business', 'In', 'America', 'is', 'Open..Everyone', 'Welcome']
# ['Fire', 'The', 'Creep', 'You', 'Call', 'Your', 'Boss!!', '26583']
# ['READ---SHIPPING', 'INSTRUTIONS--FOR', 'YOUR', 'ORDER', 'Sender:', '""', '<>', 'MIME-Version:', '1.0']
# ['Looking', 'For', 'Extra', 'Cash?', '23719']
# []
# ['Get', 'Paid', 'For', 'What', 'You', 'Know', '18436']
# ['Double', 'Your', 'Life', 'Insurance', 'at', 'NO', 'EXTRA', 'COST!', '29155']
# ['You', 'Won', 'The', 'First', 'Round!', 'claim#', '9462', '27747']
# ['Inside', 'the', 'biker', 'world']
# ['Amazing', 'Travel', 'Deals.', 'Take', 'A', 'look!']
# []
# ['I', "Can't", 'Wait', 'Anymore!']
# ['Something', 'EVERY', 'Business', 'Needs!', '[6ywab]']
# ['Something', 'EVERY', 'Business', 'Needs!', '[wxv4m]']
# []
# ['Making', 'Serious', 'Money', 'Has', 'Never', 'Been', 'This', 'Easy!', '[jodra]']
# ['Get', 'started!']
# ['Your', 'Membership', 'Exchange']
# ['re:', 'Now', 'Save', '70%', 'On', 'Your', 'Life', 'Insur', 'ance', '-', 'Free', 'Custom', 'Quote', '29658']
# []
# ['Notice']
# ['Email', 'Marketing', 'Works']
# ['Your', 'Membership', 'Community', '&', 'Commentary,', '06-29-01']
# ['Email', 'Marketing', 'Works']
# ['re.', '6.29%', 'Fixed', 'Rate', '-', 'Free', 'Instant', 'Quote', '30127']
# ['Software', 'to', 'rebuild', 'your', 'credit']
# []
# ['See', 'the', 'VIDEO', 'Britney', 'Wants', 'BANNED!']
# ["It's", 'real', 'important', 'that', 'you', 'call...']
# []
# ['Just', 'Do', 'It!']
# []
# ['Do', 'you', 'owe', 'money?', '[1njps]']
# ['Do', 'you', 'owe', 'money?', '[ovn610]']
# ['Reunion!']
# ['Remember', 'me???']
# ['Earn', '$300-$1000', 'A', 'Week', 'From', 'Your', 'Home!............', 'From:', 'jsimmons2391@yahoo.com', 'To:', 'vrotimi@allracing.com', 'Message-Id:', '<0cdt2tnnj08blir35f0.1aty3ni@mx3.mail.yahoo.com>']
# ['New', 'Accounts', '#2C6E', 'To:', 'bills39d@netnoteinc.com']
# []
# ['Free', 'money', 'from', 'the', 'government!']
# ['Get', 'Out', 'of', 'Debt', 'Fast', '29521']
# ["Here's", 'Your', 'Chance...']
# ['pmgeiser@datacomm.ch']
# ['Get', 'the', 'BEST', 'Rate', 'On', 'a', 'Home', 'Loan!']
# []
# ['Finally', 'collecct', 'your', 'judgment', '(71733)']
# ['Your', 'Membership', 'Community', '&', 'Commentary,', '07-06-01']
# []
# []
# ['Gain', 'Major', 'Cash']
# ['FW:']
# ['Get', 'Out', 'of', 'Debt', 'Fast', '12244']
# []
# ['Cd', 'Rom', '2000', 'How', 'To', 'Books']
# ['Increase', 'Sales,', 'Accept', 'Credit', 'Cards!', '[6fqtt]', 'Message-Id:', '<20010728161223.5516C11410E@mail.netnoteinc.com>']
# ['Your', 'Membership', 'Community', '&', 'Commentary,', '07-27-01']
# ['Visa', '~', 'MasterCard', '~', 'American', 'Express', '~', 'Etc.', '[6gho10]', 'Message-Id:', '<200107221658955.SM01188@jenyb.aol.com>']
# ['Visa', '~', 'MasterCard', '~', 'American', 'Express', '~', 'Etc.', '[ll4k4]', 'Message-Id:', '<200107221700768.SM01188@tmiaw.aol.com>']
# ['Get', 'Hundreds', 'Of', 'Fresh', 'Leads', 'via', 'email', '!!!']
# []
# []
# []
# ['Do', 'you', 'owe', 'the', 'IRS', 'money?', '[p5fi3]', 'Message-Id:', '<20010730015918.6A05911410E@mail.netnoteinc.com>']
# []
# ['Rates', 'Have', 'Fallen', 'Again!', '6.29%', 'Fixed', 'Rate', 'Mortgage', '9879']
# []
# ['5,000', 'OPT-IN', 'Email', 'Messages', 'ONLY', '$324.99']
# []
# []
# []
# ['100%', 'Risk-FREE', 'Way', 'To', 'Explosive', 'Profits', '!', 'Sender:', '"NetProfits"', '<netprohkg@hotmail.com>', 'MIME-Version:', '1.0']
# ['BIZZ', 'OPP', '&', 'FREE', 'Vacation', '3867']
# ['Fwd:', 'Accepting', 'Credit', 'Cards', '(Faq)', '[suhdn]', 'Message-Id:', '<20010731213620.BD9B011410E@mail.netnoteinc.com>']
# ['Fwd:', 'Accepting', 'Credit', 'Cards', '(Faq)', '[g1010pn]', 'Message-Id:', '<20010731215022.1BB3711410E@mail.netnoteinc.com>']
# ['WE', 'PAY', 'CASH,', 'NOW!', 'Content-Transfer-Encoding:', '7bit', 'Message-Id:', '<20010731231551.0823311410E@mail.netnoteinc.com>']
# ['Major', 'Stock', 'Play']
# ['All', 'Satellite', 'Channels', 'Free', '!!', '712']
# []
# ['Home', 'Loans', 'Just', 'Got', 'Better!']
# ['Major', 'Stock', 'Play']
# []
# ['Custom', 'sites', 'or', 'site', 'redesigns', '$399']
# ['Viagra', 'Online', 'Now!!', '22560']
# ['The', 'Stock', 'has', '"wow"', 'factor']
# ['Want', 'help', 'with', 'your', 'debt?', '[aiqjz]', 'Message-Id:', '<20010802003539.4B35411410E@mail.netnoteinc.com>']
# ['Viagra', 'Online', 'Now!!', '219']
# ['Do', 'you', 'have', 'enough', 'money', 'for', 'all', 'your', 'bills?', '[qmpyq]', 'Message-Id:', '<20010802011955.916E511410E@mail.netnoteinc.com>']
# ['Looking', 'for', 'Actors,', 'Models,', 'Singers', 'and', 'Dancers!!', 'Message-Id:', '<20010802022605.3A11E11410E@mail.netnoteinc.com>']
# ['YOU', 'TO', 'CAN', 'MAKE---THOUSANDS', 'PER', 'WEEK----RUNNING', 'YOUR', 'OWN', 'FREE', 'WEB', 'BUSINESS', 'Sender:', '""', '<>', 'MIME-Version:', '1.0']
# ['RE:More', 'info/grant', 'money', 'Message-Id:', '<99673281602@online-forum.net>']
# ['Expand', 'Your', 'Business!', '[wz6lo]', 'Message-Id:', '<20010802081359.9589711410E@mail.netnoteinc.com>']
# ['Your', 'Membership', 'Exchange,', '#441', 'Content-Type:', 'multipart/alternative;', 'boundary=90840724.996748272348.JavaMail.RovAdmin.rovweb003']
# []
# ['Be', 'Your', 'Own', 'Boss!!', '32140']
# ['Your', 'Membership', 'Community', '&', 'Commentary,', '08-03-01']
# ['All', 'Satellite', 'Channels', 'Free', '!!', '27886']
# ['All', 'Satellite', 'Channels', 'Free', '!!', '18441']
# Loaded 5000 input emails.
# (array([[1.000e+00, 1.000e+00, 0.000e+00, ..., 6.920e+02, 1.910e+02,
#          2.300e+02],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 4.700e+02, 2.590e+02,
#          9.300e+01],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 5.363e+03, 1.852e+03,
#          1.320e+02],
#         ...,
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00]]), array([1., 1., 1., ..., 0., 0., 0.]))
